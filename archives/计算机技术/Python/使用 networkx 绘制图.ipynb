# %% [markdown]
# # 使用 networkx 绘制图
#
# [annotation]: [id] (a088aad3-567f-41dc-872b-3d066bfd2b8f)
# [annotation]: [status] (protect)
# [annotation]: [create_time] (2021-09-12 00:08:19)
# [annotation]: [category] (计算机技术)
# [annotation]: [tags] (Python)
# [annotation]: [comments] (true)
# [annotation]: [url] (http://blog.ccyg.studio/article/a088aad3-567f-41dc-872b-3d066bfd2b8f)

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
SIZE = 10
T = nx.DiGraph()
A = np.zeros((SIZE, SIZE))

for i in range(SIZE):
    for j in range(i):
        if i == j:
            pass
        else:
            if (np.random.binomial(n=1, p=0.5, size=1) == 1)[0]:
                A[i, j] = 1
            else:
                A[j, i] = 1

for i in range(SIZE):
    for j in range(SIZE):
        if A[i][j] == 1:
            T.add_edge(i, j)

nx.draw(T)
plt.show()

# %% [markdown]
# ## 参考资料
#
# - <https://www.pythonheidong.com/blog/article/750827/18455d447f5fb653d624/>
